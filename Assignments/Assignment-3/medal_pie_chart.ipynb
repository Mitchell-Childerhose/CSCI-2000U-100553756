# %%
#Mitchell Childerhose (100553756)

from pylab import *

#Making the figure and axes
figure(1, figsize=(8,8))
ax = axes([0.1, 0.1, 0.8, 0.8])

#Assigning the data to be displayed
labels = 'USA','CHN','GBR','RUS','KOR','GER','FRA','ITA','HUN','AUS','OTHER'
fracs = [46,38,29,24,13,11,11,8,8,7,107]

pie(fracs, labels=labels,
    autopct='%1.1f%%', shadow=True, startangle=90)

#Adding the title
title('2012 Olympic gold medals (100553756)', bbox={'facecolor':'1.0', 'pad':10})

show()
