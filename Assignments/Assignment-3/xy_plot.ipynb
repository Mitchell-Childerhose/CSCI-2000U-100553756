# %%
#Mitchell Childerhose (100553756)

from matplotlib import *
from pylab import *
import numpy as np
# %matplotlib inline

figure(3, figsize=(8,8))

with open('xy_points.dat', 'r') as f:
    first_line = f.readline()
    second_line = f.readline()

x = first_line.split()
y = second_line.split()

x = [float(i) for i in x]
y = [float(j) for j in y]

xlist = []
ylist = []
xlist2 = []
ylist2 = []

for i, j in zip(x, y):
    if any((i<-2) and (-5<=j<=0)):
        xlist.append(i)
        ylist.append(j)
        
for i, j in zip(x, y):
    if any((i**2 + (j-5)**2) < 25):
        xlist2.append(i)
        ylist2.append(j)

scatter(x,y, color = 'red')
scatter(xlist2,ylist2, color = 'green')
scatter(xlist,ylist, color = 'blue')



xticks(range(-10,11), color = 'black')
yticks(range(-10,11), color = 'black')

title('Highlighted points (100553756)')
ylabel('Y', color = 'black', rotation = 0)
xlabel('X', color = 'black')

xlim(-10, 10)
ylim(-10, 10)

show()
